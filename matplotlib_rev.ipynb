# %% [markdown]
# <a href="https://colab.research.google.com/github/yazan-95/PythonUniversityUseOf/blob/main/matplotlib_rev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.array([3,6,9,11,18]))

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'ro')

# %%
t = np.arange(-2.5,2.5,0.1)

# %%
import math

y1 = np.sin(math.pi*t)
y2 = np.sin(math.pi*t+math.pi/2)
y3 = np.sin(math.pi*t-math.pi/2)

plt.plot(t,y1,'bo',t,y2,'g-.',t,y3,'y--')
plt.axis([-4,4,-2,2])
plt.title("My time series")
plt.xlabel("time")
plt.ylabel("Values")
# Out:
# Text(0, 0.5, 'Values')

# %%
plt.subplot(121)
plt.plot(t,y1,'g--')
plt.subplot(122)
plt.plot(t,y2,'r-.')
plt.grid(True)

# %%
data = {'series1':[1,3,4,3,5],'series2':[2,4,3,4,1],'series3':[3,6,1,2,2],}
df = pd.DataFrame(data)
df
# Out:
#    series1  series2  series3
# 0        1        2        3
# 1        3        4        6
# 2        4        3        1
# 3        3        4        2
# 4        5        1        2

# %%
x = np.arange(5)

# plt.axis([0,5,0,7])

# plt.plot(x,df)

df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
pop = np.random.randint(0,100,100)

# %%
plt.hist(pop,bins=20)
# Out:
# (array([ 6.,  8.,  7.,  2., 10.,  5.,  6.,  6.,  5.,  3.,  8.,  5.,  3.,
#          5.,  3.,  3.,  4.,  2.,  2.,  7.]),
#  array([ 0. ,  4.9,  9.8, 14.7, 19.6, 24.5, 29.4, 34.3, 39.2, 44.1, 49. ,
#         53.9, 58.8, 63.7, 68.6, 73.5, 78.4, 83.3, 88.2, 93.1, 98. ]),
#  <BarContainer object of 20 artists>)

# %%
index = np.arange(5)
values= [4,5,6,3,2]
plt.bar(index,values)
plt.xticks(index-0.4,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x1520ed702e0>,
# ...
#  [Text(-0.4, 0, 'A'),
#   Text(0.6, 0, 'B'),
#   Text(1.6, 0, 'C'),
#   Text(2.6, 0, 'D'),
#   Text(3.6, 0, 'E')])

# %%
x = np.linspace(1,50,50)
np.random.seed(1)
y = np.random.randint(0,20,50)
plt.plot(x,y)
plt.legend(['legend'], loc=7)
plt.show()

# %%
plt.figure(figsize=(8,4))

x = ['Arjun', 'Bharath', 'Raju', 'Seeta', 'Ram']
y = [5, 7, 8, 4, 6]

plt.bar(x,y,color='g')
plt.xlabel('Students', fontsize = 30)
plt.ylabel('Marks', fontsize = 30)

plt.legend(['Marks scored'],loc=6)

plt.show()

# %%
from pylab import *

x = np.linspace(0, (2*np.pi), endpoint = True)

xlim(x.min(), x.max())

xticks([0, np.pi/2, np.pi, (3*np.pi/2), (2*np.pi)],
       [r'$0$', r'$+\pi/2$', r'$+\pi$', r'$3/2\pi$', r'$2\pi$'])

ylim(-1, 0, 1)
yticks([-1, 0, +1],
       [r'$-1$', r'$0$', r'$+1$'])

plt.plot(x, np.sin(x), label = "sin(x)")
plt.plot(x, np.cos(x), label = "cos(x)")

plt.title('Trigonometric Functions', fontsize = 22)

plt.xlabel('Angles', fontsize = 20)
plt.ylabel('Values', fontsize = 20)

plt.legend(loc = 'upper center')

plt.rc('legend', fontsize = 16)

plt.grid()
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, popularity, color=(0.4, 0.6, 0.8, 1.0), edgecolor='blue')

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")
plt.xticks(x_pos, x)

plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')

plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
