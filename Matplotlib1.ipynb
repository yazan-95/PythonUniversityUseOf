# %% [markdown]
# <a href="https://colab.research.google.com/github/yazan-95/PythonUniversityUseOf/blob/main/Matplotlib1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## importing The important packages ###
import datetime as DT
from matplotlib import pyplot as plt
from matplotlib.dates import date2num

# %%
### First Question Solution ###
print("HomeWork_3\nFirst Question\n\n")

data = [(DT.datetime.strptime('2016-10-03', "%Y-%m-%d"), 772.559998),

        (DT.datetime.strptime('2016-10-04', "%Y-%m-%d"), 776.429993),

        (DT.datetime.strptime('2016-10-05', "%Y-%m-%d"), 776.469971),

        (DT.datetime.strptime('2016-10-06', "%Y-%m-%d"), 776.859985),

        (DT.datetime.strptime('2016-10-07', "%Y-%m-%d"), 775.080017 )]

x = [date2num(date) for (date, value) in data]
y = [value for (date, value) in data]

fig = plt.figure()

graph = fig.add_subplot(111)

graph.plot(x,y,'k-*')

graph.set_xticks(x)

graph.set_xticklabels( [date.strftime("%Y-%m-%d") for (date, value) in data] )

plt.xlabel('Dates')

plt.ylabel('Closing Values')

plt.title('Closing values of Alphabet Inc.')

plt.grid(linestyle='-', linewidth='0.5', color='blue')

plt.show()
# Out:
# HomeWork_3
# First Question

# %%
### Second Question Solution ###
print("HomeWork_3\nSecond Question\n\n")

x = ['Java', 'Python', 'PHP', 'JScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]


x_pos = [i for i, _ in enumerate(x)]
plt.bar(x_pos, popularity, color='purple')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")
plt.xticks(x_pos, x)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# HomeWork_3
# Second Question
